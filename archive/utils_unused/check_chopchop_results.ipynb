# %%
import pandas as pd

df = pd.read_csv('../../data/output/chopchop_scores/kmarxianus/output_0.csv', sep='\t')

df.sort_values(by=['Efficiency'])
# Out:
#      Rank          Target sequence     Genomic location Strand  \
# 346   347  ATGTCCGTTAGTATCTTAGCGGG     XP_022676747.1:1      +
# 345   346  ATAGCTTCTCTGGCCATTTTTGG  XP_022676747.1:1936      -
# 368   369  AGGTTTCTTAGAATCTATTTTGG  XP_022676747.1:2712      +
# 344   345  CAAATGTATCTTCTCTTTCTTGG  XP_022676747.1:3504      -
# 343   344  AAGAGTAAATGTGGTCTTTCTGG  XP_022676747.1:1081      +
# ..    ...                      ...                  ...    ...
# 2       3  TCAACGCGTAGTGCAAACCTGGG  XP_022676747.1:3174      -
# 12     13  GTTATCTGAATAAGCAGACACGG   XP_022676747.1:854      -
# 1       2  CCATTGTTGAGCAAAGAGAGTGG  XP_022676747.1:2557      +
# 0       1  TGTCAAGTGCAGATGCGATGTGG  XP_022676747.1:1173      -
# 347   348  AAACATGAGTGAACAATACGAGG  XP_022676747.1:3612      +
#
#      GC content (%)  Self-complementarity  MM0  MM1  MM2  MM3  Efficiency
# 346              40                     0    1    0    0    0        0.00
# ...
