# %%
import pandas as pd

df = pd.read_csv('../removed_guides.csv')

df.head()
# Out:
#           removed_guide                   species strand       seq_id  \
# 0  ACTGATTTTACGTACGCACA  saccharomyces_cerevisiae      F  NC_001133.9
# 1  TGCACTCACATCATTATGCA  saccharomyces_cerevisiae      F  NC_001133.9
# 2  TTTGATATCTATATCTCATT  saccharomyces_cerevisiae      F  NC_001133.9
# 3  GATATCTATATCTCATTCGG  saccharomyces_cerevisiae      F  NC_001133.9
# 4  ACAATAATACATAAACATAT  saccharomyces_cerevisiae      F  NC_001133.9
#
#    location  total_seq_length  proportion_of_total_location  \
# 0       432            230218                      0.001876
# 1       542            230218                      0.002354
# 2       626            230218                      0.002719
# 3       629            230218                      0.002732
# 4       798            230218                      0.003466
#
#    contains_nonstandard  contains_fourmers  contains_fivemers  \
# 0                     0                  1                  0
# ...

# %%
scer = df[df['species'] == 'saccharomyces_cerevisiae']

# %%
import seaborn as sns
import matplotlib.pyplot as plt


fig = plt.figure(figsize=(15, 6))

sns.violinplot(
    x='seq_id',
    y='proportion_of_total_location',
    data=df[df['species'] == 'saccharomyces_cerevisiae'],
    inner=None
    )

plt.ylim(0, 1)
plt.xticks(rotation=90)
# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt


fig = plt.figure(figsize=(15, 6))

sns.violinplot(
    x='seq_id',
    y='proportion_of_total_location',
    data=df[(df['species'] == 'saccharomyces_cerevisiae') & ((df['contains_fourmers'] == 1) | (df['contains_fivemers'] == 1))],
    inner=None
    )

plt.ylim(0, 1)
plt.xticks(rotation=90)
# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt


fig = plt.figure(figsize=(15, 6))

sns.violinplot(
    x='seq_id',
    y='proportion_of_total_location',
    data=df[(df['species'] == 'saccharomyces_cerevisiae') & (df['contains_five_or_more_rep_twomers'] == 1)],
    inner=None
    )

plt.ylim(0, 1)
plt.xticks(rotation=90)
# Show the plot
plt.show()
