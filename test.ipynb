# %%
import pandas as pd

soi = ['kluyveromyces_marxianus', 'komagataella_phaffii', 'yarrowia_lipolytica']

df = pd.read_csv('data/input/fourdbs_hi_input_species.csv')

df
# Out:
#                     species_name  \
# 0       saccharomyces_cerevisiae
# 1             fusarium_oxysporum
# 2               candida_albicans
# 3        cryptococcus_neoformans
# 4     saccharomyces_kudriavzevii
# ...                          ...
# 2429     achaetomium_macrosporum
# 2430         acarospora_strigata
# 2431             absidia_padenii
# 2432            absidia_caerulea
# 2433         abortiporus_biennis
#
#                                        genome_file_name  \
# 0                  saccharomyces_cerevisiae_genomic.fna
# 1                        fusarium_oxysporum_genomic.fna
# 2                          candida_albicans_genomic.fna
# 3                   cryptococcus_neoformans_genomic.fna
# 4                saccharomyces_kudriavzevii_genomic.fna
# ...                                                 ...
# 2429  achaetomium_macrosporum_cbs_532_94_v1_0_genomi...
# 2430         acarospora_strigata_cbs_132363_genomic.fna
# ...

# %%
df[~df['species_name'].isin(soi)].reset_index(drop=True).to_csv('data/input/fourdbs_hi_without_3soi.csv', index=False)

# %%
import shutil
import os

for r in range(80):
    if os.path.exists(f'data/output/a1_cv_split_1_run_{r}_1'):
        shutil.rmtree(f'data/output/a1_cv_split_1_run_{r}_1')

# %%
new_exp_name = f'a1_cv_split_1_run_0'

if not os.path.exists(f'data/output/test_{new_exp_name}_results.csv'):
    print('lol')

# %%
f'data/output/test_{new_exp_name}_results.csv'
# Out:
# 'data/output/test_a1_cv_split_1_run_0_results.csv'

# %%
os.path.exists(f'data/output/test_{new_exp_name}_results.csv')
# Out:
# False
